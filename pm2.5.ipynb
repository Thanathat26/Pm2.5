# %%
import pandas as pd
air25_data = pd.read_csv('airbin.csv')
air25_data
# Out:
#     Unnamed: 0         DATETIMEDATA  PM25  PM10    O3  CO  NO2  SO2  WS  TEMP  \
# 0            0  2024-02-19 00:00:00  14.4   NaN  18.0 NaN  NaN  NaN   1    28
# 1            1  2024-02-19 01:00:00  17.5   NaN  17.0 NaN  NaN  NaN   1    28
# 2            2  2024-02-19 02:00:00  14.0   NaN  18.0 NaN  NaN  NaN   0    28
# 3            3  2024-02-19 03:00:00  13.6   NaN  18.0 NaN  NaN  NaN   1    28
# 4            4  2024-02-19 04:00:00  14.4   NaN  17.0 NaN  NaN  NaN   1    27
# 5            5  2024-02-19 05:00:00  13.2   NaN  18.0 NaN  NaN  NaN   1    27
# 6            6  2024-02-19 06:00:00  13.5   NaN  15.0 NaN  NaN  NaN   0    27
# 7            7  2024-02-19 07:00:00  19.7   NaN  14.0 NaN  NaN  NaN   1    28
# 8            8  2024-02-19 08:00:00  19.0   NaN  18.0 NaN  NaN  NaN   1    29
# 9            9  2024-02-19 09:00:00  10.2   NaN   NaN NaN  NaN  NaN   1    31
# 10          10  2024-02-19 10:00:00  13.5   NaN  22.0 NaN  NaN  NaN   1    31
# ...

# %%
air25_data.describe()
# Out:
#        Unnamed: 0       PM25  PM10         O3   CO  NO2  SO2         WS  \
# count   34.000000  34.000000   0.0  33.000000  0.0  0.0  0.0  34.000000
# mean    16.500000  16.205882   NaN  16.272727  NaN  NaN  NaN   0.764706
# std      9.958246   5.319543   NaN   6.175925  NaN  NaN  NaN   0.495973
# min      0.000000   8.500000   NaN   3.000000  NaN  NaN  NaN   0.000000
# 25%      8.250000  13.050000   NaN  15.000000  NaN  NaN  NaN   0.250000
# 50%     16.500000  14.400000   NaN  18.000000  NaN  NaN  NaN   1.000000
# 75%     24.750000  19.000000   NaN  19.000000  NaN  NaN  NaN   1.000000
# max     33.000000  31.400000   NaN  26.000000  NaN  NaN  NaN   2.000000
#
#             TEMP         RH          WD
# count  34.000000  34.000000   34.000000
# mean   28.794118  72.705882  118.323529
# std     1.981420  10.718235   21.704239
# min    26.000000  52.000000   93.000000
# 25%    27.000000  62.750000  106.000000
# 50%    28.000000  76.000000  111.000000
# ...

# %%
air25_data.isnull().sum()
# Out:
# Unnamed: 0       0
# DATETIMEDATA     0
# PM25             0
# PM10            34
# O3               1
# CO              34
# NO2             34
# SO2             34
# WS               0
# TEMP             0
# RH               0
# WD               0
# dtype: int64

# %%
nan_col=['CO','NO2','SO2','PM10',]
air25_data = air25_data.drop(columns=nan_col)
air25_data.dropna(subset='O3', inplace=True)
air25_data
# Out:
#     Unnamed: 0         DATETIMEDATA  PM25    O3  WS  TEMP  RH   WD
# 0            0  2024-02-19 00:00:00  14.4  18.0   1    28  76  108
# 1            1  2024-02-19 01:00:00  17.5  17.0   1    28  76  106
# 2            2  2024-02-19 02:00:00  14.0  18.0   0    28  76  104
# 3            3  2024-02-19 03:00:00  13.6  18.0   1    28  74   96
# 4            4  2024-02-19 04:00:00  14.4  17.0   1    27  78   94
# 5            5  2024-02-19 05:00:00  13.2  18.0   1    27  78  102
# 6            6  2024-02-19 06:00:00  13.5  15.0   0    27  78  102
# 7            7  2024-02-19 07:00:00  19.7  14.0   1    28  76   96
# 8            8  2024-02-19 08:00:00  19.0  18.0   1    29  71  112
# 10          10  2024-02-19 10:00:00  13.5  22.0   1    31  57  136
# 11          11  2024-02-19 11:00:00  14.4  22.0   1    32  55  147
# 12          12  2024-02-19 12:00:00  14.7  24.0   2    32  55  139
# 13          13  2024-02-19 13:00:00  10.6  23.0   1    33  52  155
# ...

# %%
air25_data.to_csv("clean_data.csv", index=False)

# %%
import pandas as pd
data = pd.read_csv('Clean_data.csv')
data
# Out:
#     Unnamed: 0         DATETIMEDATA  PM25    O3  WS  TEMP  RH   WD
# 0            0  2024-02-19 00:00:00  14.4  18.0   1    28  76  108
# 1            1  2024-02-19 01:00:00  17.5  17.0   1    28  76  106
# 2            2  2024-02-19 02:00:00  14.0  18.0   0    28  76  104
# 3            3  2024-02-19 03:00:00  13.6  18.0   1    28  74   96
# 4            4  2024-02-19 04:00:00  14.4  17.0   1    27  78   94
# 5            5  2024-02-19 05:00:00  13.2  18.0   1    27  78  102
# 6            6  2024-02-19 06:00:00  13.5  15.0   0    27  78  102
# 7            7  2024-02-19 07:00:00  19.7  14.0   1    28  76   96
# 8            8  2024-02-19 08:00:00  19.0  18.0   1    29  71  112
# 9           10  2024-02-19 10:00:00  13.5  22.0   1    31  57  136
# 10          11  2024-02-19 11:00:00  14.4  22.0   1    32  55  147
# 11          12  2024-02-19 12:00:00  14.7  24.0   2    32  55  139
# 12          13  2024-02-19 13:00:00  10.6  23.0   1    33  52  155
# ...

# %%
data["PM25"].plot()
# Out:
# <Axes: >

# %%
data.dtypes
# Out:
# Unnamed: 0               int64
# DATETIMEDATA    datetime64[ns]
# PM25                   float64
# O3                     float64
# WS                       int64
# TEMP                     int64
# RH                       int64
# WD                       int64
# dtype: object

# %%
data["DATETIMEDATA"] = pd.to_datetime(data["DATETIMEDATA"])

# %%
data.plot()
# Out:
# <Axes: >
